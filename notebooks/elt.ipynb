# %%
# !pip install psycopg2-binary
# !pip install python-dotenv
# Out:
# Requirement already satisfied: psycopg2-binary in d:\tool\tool_anaconda\py_thon\lib\site-packages (2.9.11)
# Requirement already satisfied: python-dotenv in d:\tool\tool_anaconda\py_thon\lib\site-packages (1.1.0)

# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Đọc file CSV
df = pd.read_csv('sale_query.csv')

print("Data preview:")
print(df.head())
# Out:
# Data preview:
#          date  day     month  year  customer_age       age_group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   customer_gender    country             state product_category sub_category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                product  order_quantity  unit_cost  unit_price  profit  cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %%
# test Read CSV
from dotenv import load_dotenv
import os

load_dotenv("password.env")

print("USER:", os.getenv("DB_USER"))
print("PASSWORD:", os.getenv("DB_PASSWORD"))
# Out:
# USER: postgres
# PASSWORD: 692002

# %%
# connect database
from sqlalchemy import create_engine
import os

username = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
database = os.getenv("DB_NAME")

engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')

# test kết nối
engine.connect()

print("Connected successfully!")
# Out:
# Connected successfully!

# %%
#load CSV
import pandas as pd

df = pd.read_csv('sale_query.csv')  

print(df.head())
# Out:
#          date  day     month  year  customer_age       age_group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   customer_gender    country             state product_category sub_category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                product  order_quantity  unit_cost  unit_price  profit  cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %%
# Inset database
import pandas as pd

df = pd.read_csv('sale_query.csv')

df.to_sql('sales_raw', engine, if_exists='replace', index=False)

print("DONE")
# Out:
# DONE
